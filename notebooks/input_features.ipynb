# %%
#region: NOTEBOOK SPECIFIC IMPORTS
import os
os.chdir('<path to cloned git repository folder>/rapid-soh-estimation-from-short-pulses')

from rapid_soh_estimation.rapid_soh_estimation.config import *
from rapid_soh_estimation.rapid_soh_estimation.common_methods import *
#endregion END NOTEBOOK SPECIFIC IMPORTS

# %% [markdown]
# ### Aging Trajectory of the 11 Groups in the LFP/Gr Data

# %%
from rapid_soh_estimation.rapid_soh_estimation.plotting import plot_aging_trajectories

plot_aging_trajectories(save=False)

# %% [markdown]
# ### Visual Overview of the 100-Seconds Pulses

# %%
from rapid_soh_estimation.rapid_soh_estimation.plotting import plot_rpt_section_pulses
plot_rpt_section_pulses(pulse_type='chg', stack_horizontal=True, save=False)

# %%
from rapid_soh_estimation.rapid_soh_estimation.plotting import plot_pulse_capacity_fade
plot_pulse_capacity_fade(pulse_type='chg', save=False)

# %% [markdown]
# ### Visual Overview of the Voltage Subsampling during the 1C CC-CV Charge

# %%
from rapid_soh_estimation.rapid_soh_estimation.plotting import plot_cc_input_comparison

plot_cc_input_comparison(save=False)
